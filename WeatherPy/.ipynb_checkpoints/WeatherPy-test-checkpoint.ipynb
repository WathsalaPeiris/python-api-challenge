# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 618

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
   
    # Create endpoint URL with each city
    
    response = requests.get(query_url+city).json()
    
response
# Out:
# {'coord': {'lon': -80.6094, 'lat': 51.2585},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': -8.01,
#   'feels_like': -12.6,
#   'temp_min': -8.01,
#   'temp_max': -7,
#   'pressure': 1009,
#   'humidity': 93},
#  'visibility': 10000,
#  'wind': {'speed': 2.57, 'deg': 220},
#  'clouds': {'all': 100},
#  'dt': 1674394752,
#  'sys': {'type': 1,
#   'id': 860,
#   'country': 'CA',
#   'sunrise': 1674393211,
#   'sunset': 1674424445},
#  'timezone': -18000,
#  'id': 6078372,
#  'name': 'Moose Factory',
#  'cod': 200}

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
base_url = f"{url}appid={weather_api_key}&units={units}&q="


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = base_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat,
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | faanui
# Processing Record 2 of Set 1 | wichita falls
# Processing Record 3 of Set 1 | busselton
# Processing Record 4 of Set 1 | carnarvon
# Processing Record 5 of Set 1 | saint george
# Processing Record 6 of Set 1 | marzuq
# Processing Record 7 of Set 1 | burnie
# Processing Record 8 of Set 1 | georgetown
# Processing Record 9 of Set 1 | provideniya
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | tilichiki
# Processing Record 12 of Set 1 | severo-kurilsk
# Processing Record 13 of Set 1 | tuktoyaktuk
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | mungwi
# Processing Record 16 of Set 1 | port hedland
# Processing Record 17 of Set 1 | qaanaaq
# Processing Record 18 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 1 | luang prabang
# Processing Record 20 of Set 1 | yellowknife
# Processing Record 21 of Set 1 | cape town
# Processing Record 22 of Set 1 | san cristobal
# Processing Record 23 of Set 1 | khatanga
# Processing Record 24 of Set 1 | bara
# Processing Record 25 of Set 1 | upernavik
# Processing Record 26 of Set 1 | praia da vitoria
# Processing Record 27 of Set 1 | avarua
# Processing Record 28 of Set 1 | mahebourg
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | verkhoturye
# Processing Record 31 of Set 1 | longyearbyen
# Processing Record 32 of Set 1 | narsaq
# Processing Record 33 of Set 1 | svetlogorsk
# Processing Record 34 of Set 1 | isangel
# Processing Record 35 of Set 1 | bethel
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | hilo
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | east london
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | mpika
# Processing Record 44 of Set 1 | xapuri
# Processing Record 45 of Set 1 | saskylakh
# Processing Record 46 of Set 1 | taoudenni
# Processing Record 47 of Set 1 | mataura
# Processing Record 48 of Set 1 | khromtau
# Processing Record 49 of Set 1 | odessa
# Processing Record 50 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 0 of Set 2 | lasa
# Processing Record 1 of Set 2 | yenagoa
# Processing Record 2 of Set 2 | margate
# Processing Record 3 of Set 2 | ahipara
# Processing Record 4 of Set 2 | grindavik
# Processing Record 5 of Set 2 | elat
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | biltine
# Processing Record 8 of Set 2 | victoria
# Processing Record 9 of Set 2 | puerto ayora
# Processing Record 10 of Set 2 | port alfred
# Processing Record 11 of Set 2 | hasaki
# Processing Record 12 of Set 2 | san patricio
# Processing Record 13 of Set 2 | blonduos
# City not found. Skipping...
# Processing Record 14 of Set 2 | honiara
# Processing Record 15 of Set 2 | gimangpang
# City not found. Skipping...
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | cockburn town
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | lompoc
# Processing Record 21 of Set 2 | mareeba
# Processing Record 22 of Set 2 | atuona
# Processing Record 23 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 2 | ilulissat
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | kununurra
# Processing Record 27 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 2 | cabra
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | inisa
# Processing Record 31 of Set 2 | havelock
# Processing Record 32 of Set 2 | kahului
# Processing Record 33 of Set 2 | toamasina
# Processing Record 34 of Set 2 | puerto escondido
# Processing Record 35 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 2 | lazaro cardenas
# Processing Record 37 of Set 2 | tura
# Processing Record 38 of Set 2 | bredasdorp
# Processing Record 39 of Set 2 | saldanha
# Processing Record 40 of Set 2 | ketchikan
# Processing Record 41 of Set 2 | luwuk
# Processing Record 42 of Set 2 | kyren
# Processing Record 43 of Set 2 | yaan
# Processing Record 44 of Set 2 | ossora
# Processing Record 45 of Set 2 | verkhnyaya inta
# Processing Record 46 of Set 2 | half moon bay
# Processing Record 47 of Set 2 | butaritari
# Processing Record 48 of Set 2 | mount gambier
# Processing Record 49 of Set 2 | vinukonda
# Processing Record 0 of Set 3 | calamar
# Processing Record 1 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 2 of Set 3 | tiksi
# Processing Record 3 of Set 3 | lashma
# Processing Record 4 of Set 3 | sur
# Processing Record 5 of Set 3 | fiumicino
# Processing Record 6 of Set 3 | port blair
# Processing Record 7 of Set 3 | gushikawa
# Processing Record 8 of Set 3 | bluff
# Processing Record 9 of Set 3 | pangkalanbuun
# Processing Record 10 of Set 3 | new norfolk
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | port hardy
# Processing Record 13 of Set 3 | cabo san lucas
# Processing Record 14 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 15 of Set 3 | kotovo
# Processing Record 16 of Set 3 | naantali
# Processing Record 17 of Set 3 | sinnamary
# Processing Record 18 of Set 3 | salalah
# Processing Record 19 of Set 3 | necochea
# Processing Record 20 of Set 3 | faya
# Processing Record 21 of Set 3 | manicore
# Processing Record 22 of Set 3 | carutapera
# Processing Record 23 of Set 3 | cheuskiny
# City not found. Skipping...
# Processing Record 24 of Set 3 | arica
# Processing Record 25 of Set 3 | nizhneangarsk
# Processing Record 26 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 3 | asau
# Processing Record 28 of Set 3 | gravdal
# Processing Record 29 of Set 3 | brae
# Processing Record 30 of Set 3 | nikolskoye
# Processing Record 31 of Set 3 | luwingu
# Processing Record 32 of Set 3 | katsuura
# Processing Record 33 of Set 3 | ayr
# Processing Record 34 of Set 3 | srednekolymsk
# Processing Record 35 of Set 3 | kalakamati
# Processing Record 36 of Set 3 | egvekinot
# Processing Record 37 of Set 3 | liniere
# City not found. Skipping...
# Processing Record 38 of Set 3 | banda aceh
# Processing Record 39 of Set 3 | jiquipilas
# Processing Record 40 of Set 3 | poum
# Processing Record 41 of Set 3 | chalmette
# Processing Record 42 of Set 3 | la tuque
# Processing Record 43 of Set 3 | rizhao
# Processing Record 44 of Set 3 | sechura
# Processing Record 45 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 3 | saint anthony
# Processing Record 48 of Set 3 | tucumcari
# Processing Record 49 of Set 3 | talnakh
# Processing Record 0 of Set 4 | buta
# Processing Record 1 of Set 4 | college
# Processing Record 2 of Set 4 | houma
# Processing Record 3 of Set 4 | sibiti
# Processing Record 4 of Set 4 | lebu
# Processing Record 5 of Set 4 | virginia beach
# Processing Record 6 of Set 4 | carmarthen
# Processing Record 7 of Set 4 | kavieng
# Processing Record 8 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 9 of Set 4 | areosa
# Processing Record 10 of Set 4 | haines junction
# Processing Record 11 of Set 4 | san quintin
# Processing Record 12 of Set 4 | kenai
# Processing Record 13 of Set 4 | thompson
# Processing Record 14 of Set 4 | aasiaat
# Processing Record 15 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 16 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 4 | norman wells
# Processing Record 18 of Set 4 | goderich
# Processing Record 19 of Set 4 | nizwa
# Processing Record 20 of Set 4 | parana
# Processing Record 21 of Set 4 | elliot lake
# Processing Record 22 of Set 4 | esperance
# Processing Record 23 of Set 4 | masvingo
# Processing Record 24 of Set 4 | cherepovets
# Processing Record 25 of Set 4 | ilhabela
# Processing Record 26 of Set 4 | olafsvik
# Processing Record 27 of Set 4 | mwanza
# Processing Record 28 of Set 4 | fukue
# Processing Record 29 of Set 4 | port lincoln
# Processing Record 30 of Set 4 | komsomolskiy
# Processing Record 31 of Set 4 | banjar
# Processing Record 32 of Set 4 | krasnyy chikoy
# Processing Record 33 of Set 4 | peleduy
# Processing Record 34 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 35 of Set 4 | yuanping
# Processing Record 36 of Set 4 | manamadurai
# Processing Record 37 of Set 4 | cidreira
# Processing Record 38 of Set 4 | nanticoke
# Processing Record 39 of Set 4 | whittlesea
# Processing Record 40 of Set 4 | sitka
# Processing Record 41 of Set 4 | alofi
# Processing Record 42 of Set 4 | bandar-e anzali
# Processing Record 43 of Set 4 | charlestown
# Processing Record 44 of Set 4 | russell
# Processing Record 45 of Set 4 | okhotsk
# Processing Record 46 of Set 4 | saint-philippe
# Processing Record 47 of Set 4 | kaitangata
# Processing Record 48 of Set 4 | jalu
# Processing Record 49 of Set 4 | waltershausen
# Processing Record 0 of Set 5 | caravelas
# Processing Record 1 of Set 5 | albany
# Processing Record 2 of Set 5 | wainwright
# Processing Record 3 of Set 5 | fairbanks
# Processing Record 4 of Set 5 | hamilton
# Processing Record 5 of Set 5 | banita
# Processing Record 6 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 7 of Set 5 | woodward
# Processing Record 8 of Set 5 | yirol
# City not found. Skipping...
# Processing Record 9 of Set 5 | birjand
# Processing Record 10 of Set 5 | balakhta
# Processing Record 11 of Set 5 | mar del plata
# Processing Record 12 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 5 | fort morgan
# Processing Record 14 of Set 5 | tasiilaq
# Processing Record 15 of Set 5 | teguldet
# Processing Record 16 of Set 5 | cherskiy
# Processing Record 17 of Set 5 | chanthaburi
# Processing Record 18 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 5 | flinders
# Processing Record 21 of Set 5 | yertsevo
# Processing Record 22 of Set 5 | bambous virieux
# Processing Record 23 of Set 5 | nola
# Processing Record 24 of Set 5 | zuenoula
# Processing Record 25 of Set 5 | adrar
# Processing Record 26 of Set 5 | chokurdakh
# Processing Record 27 of Set 5 | sorland
# Processing Record 28 of Set 5 | naftah
# City not found. Skipping...
# Processing Record 29 of Set 5 | manacapuru
# Processing Record 30 of Set 5 | dikson
# Processing Record 31 of Set 5 | mayumba
# Processing Record 32 of Set 5 | samarai
# Processing Record 33 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 5 | bawisan
# City not found. Skipping...
# Processing Record 35 of Set 5 | sonqar
# City not found. Skipping...
# Processing Record 36 of Set 5 | kampot
# Processing Record 37 of Set 5 | maliq
# Processing Record 38 of Set 5 | rocha
# Processing Record 39 of Set 5 | guerrero negro
# Processing Record 40 of Set 5 | honningsvag
# Processing Record 41 of Set 5 | karratha
# Processing Record 42 of Set 5 | chuy
# Processing Record 43 of Set 5 | itanagar
# Processing Record 44 of Set 5 | manggar
# Processing Record 45 of Set 5 | sotnikovo
# Processing Record 46 of Set 5 | tara
# Processing Record 47 of Set 5 | selenginsk
# Processing Record 48 of Set 5 | sao felix do xingu
# Processing Record 49 of Set 5 | pontianak
# Processing Record 0 of Set 6 | solnechnyy
# Processing Record 1 of Set 6 | bongandanga
# Processing Record 2 of Set 6 | jalgaon
# Processing Record 3 of Set 6 | bilma
# Processing Record 4 of Set 6 | belmonte
# Processing Record 5 of Set 6 | nanortalik
# Processing Record 6 of Set 6 | airai
# Processing Record 7 of Set 6 | great yarmouth
# Processing Record 8 of Set 6 | buritis
# Processing Record 9 of Set 6 | rawson
# Processing Record 10 of Set 6 | seoul
# Processing Record 11 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 6 | luderitz
# Processing Record 13 of Set 6 | yulara
# Processing Record 14 of Set 6 | aklavik
# Processing Record 15 of Set 6 | kargasok
# Processing Record 16 of Set 6 | gat
# Processing Record 17 of Set 6 | porto torres
# Processing Record 18 of Set 6 | coquimbo
# Processing Record 19 of Set 6 | geraldton
# Processing Record 20 of Set 6 | naze
# Processing Record 21 of Set 6 | doha
# Processing Record 22 of Set 6 | fort nelson
# Processing Record 23 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 6 | labuhan
# Processing Record 25 of Set 6 | limbang
# Processing Record 26 of Set 6 | bundaberg
# Processing Record 27 of Set 6 | ribeira grande
# Processing Record 28 of Set 6 | tambul
# City not found. Skipping...
# Processing Record 29 of Set 6 | finnsnes
# Processing Record 30 of Set 6 | carndonagh
# Processing Record 31 of Set 6 | khonuu
# City not found. Skipping...
# Processing Record 32 of Set 6 | santiago del estero
# Processing Record 33 of Set 6 | zapresic
# Processing Record 34 of Set 6 | altay
# Processing Record 35 of Set 6 | natchez
# Processing Record 36 of Set 6 | rio gallegos
# Processing Record 37 of Set 6 | culebra
# Processing Record 38 of Set 6 | maniitsoq
# Processing Record 39 of Set 6 | bachaquero
# Processing Record 40 of Set 6 | prince rupert
# Processing Record 41 of Set 6 | vao
# Processing Record 42 of Set 6 | palestine
# Processing Record 43 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 44 of Set 6 | yeppoon
# Processing Record 45 of Set 6 | husavik
# Processing Record 46 of Set 6 | koygorodok
# Processing Record 47 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 48 of Set 6 | nazilli
# Processing Record 49 of Set 6 | jalingo
# Processing Record 0 of Set 7 | sandwick
# Processing Record 1 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 7 | havre-saint-pierre
# Processing Record 3 of Set 7 | murdochville
# Processing Record 4 of Set 7 | beisfjord
# Processing Record 5 of Set 7 | changji
# Processing Record 6 of Set 7 | eureka
# Processing Record 7 of Set 7 | wajima
# Processing Record 8 of Set 7 | nome
# Processing Record 9 of Set 7 | saint-augustin
# Processing Record 10 of Set 7 | aksay
# Processing Record 11 of Set 7 | cabedelo
# Processing Record 12 of Set 7 | kilindoni
# Processing Record 13 of Set 7 | caronport
# Processing Record 14 of Set 7 | daru
# Processing Record 15 of Set 7 | zhezkazgan
# Processing Record 16 of Set 7 | carahue
# Processing Record 17 of Set 7 | ust-kuyga
# Processing Record 18 of Set 7 | kalmunai
# Processing Record 19 of Set 7 | sao filipe
# Processing Record 20 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 21 of Set 7 | talara
# Processing Record 22 of Set 7 | moree
# Processing Record 23 of Set 7 | gurgan
# City not found. Skipping...
# Processing Record 24 of Set 7 | gorontalo
# Processing Record 25 of Set 7 | westport
# Processing Record 26 of Set 7 | portland
# Processing Record 27 of Set 7 | bambanglipuro
# Processing Record 28 of Set 7 | zabid
# Processing Record 29 of Set 7 | cabatuan
# Processing Record 30 of Set 7 | umm lajj
# Processing Record 31 of Set 7 | paciran
# Processing Record 32 of Set 7 | arman
# Processing Record 33 of Set 7 | southport
# Processing Record 34 of Set 7 | henties bay
# Processing Record 35 of Set 7 | lyaskelya
# Processing Record 36 of Set 7 | pringsewu
# Processing Record 37 of Set 7 | namatanai
# Processing Record 38 of Set 7 | khomeynishahr
# City not found. Skipping...
# Processing Record 39 of Set 7 | broome
# Processing Record 40 of Set 7 | arraial do cabo
# Processing Record 41 of Set 7 | puerto leguizamo
# Processing Record 42 of Set 7 | kodiak
# Processing Record 43 of Set 7 | combita
# Processing Record 44 of Set 7 | souillac
# Processing Record 45 of Set 7 | berlevag
# Processing Record 46 of Set 7 | acarau
# Processing Record 47 of Set 7 | novopokrovskaya
# Processing Record 48 of Set 7 | hami
# Processing Record 49 of Set 7 | nantucket
# Processing Record 0 of Set 8 | chingola
# Processing Record 1 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 2 of Set 8 | lata
# Processing Record 3 of Set 8 | tarakan
# Processing Record 4 of Set 8 | omboue
# Processing Record 5 of Set 8 | plettenberg bay
# Processing Record 6 of Set 8 | ilorin
# Processing Record 7 of Set 8 | east moline
# Processing Record 8 of Set 8 | khunti
# Processing Record 9 of Set 8 | chimbote
# Processing Record 10 of Set 8 | paamiut
# Processing Record 11 of Set 8 | igboho
# Processing Record 12 of Set 8 | anchorage
# Processing Record 13 of Set 8 | road town
# Processing Record 14 of Set 8 | alta floresta
# Processing Record 15 of Set 8 | shebunino
# Processing Record 16 of Set 8 | aktau
# Processing Record 17 of Set 8 | minas
# Processing Record 18 of Set 8 | lincoln
# Processing Record 19 of Set 8 | heiloo
# Processing Record 20 of Set 8 | emerald
# Processing Record 21 of Set 8 | kirensk
# Processing Record 22 of Set 8 | sept-iles
# Processing Record 23 of Set 8 | paita
# Processing Record 24 of Set 8 | plymouth
# Processing Record 25 of Set 8 | lodja
# Processing Record 26 of Set 8 | sylva
# Processing Record 27 of Set 8 | la motte-servolex
# Processing Record 28 of Set 8 | kamenka
# Processing Record 29 of Set 8 | hithadhoo
# Processing Record 30 of Set 8 | taozhuang
# Processing Record 31 of Set 8 | surt
# Processing Record 32 of Set 8 | tiarei
# Processing Record 33 of Set 8 | haapiti
# Processing Record 34 of Set 8 | matehuala
# Processing Record 35 of Set 8 | richards bay
# Processing Record 36 of Set 8 | dongli
# Processing Record 37 of Set 8 | kalianget
# Processing Record 38 of Set 8 | carballo
# Processing Record 39 of Set 8 | dzaoudzi
# Processing Record 40 of Set 8 | alexandria
# Processing Record 41 of Set 8 | baruun-urt
# Processing Record 42 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 8 | kisarazu
# Processing Record 44 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 8 | yar-sale
# Processing Record 46 of Set 8 | pacific grove
# Processing Record 47 of Set 8 | moron
# Processing Record 48 of Set 8 | saint-joseph
# Processing Record 49 of Set 8 | cayenne
# Processing Record 0 of Set 9 | chail
# Processing Record 1 of Set 9 | velizh
# Processing Record 2 of Set 9 | pisco
# Processing Record 3 of Set 9 | kruisfontein
# Processing Record 4 of Set 9 | chernyshkovskiy
# Processing Record 5 of Set 9 | mekhe
# Processing Record 6 of Set 9 | allanmyo
# City not found. Skipping...
# Processing Record 7 of Set 9 | trelew
# Processing Record 8 of Set 9 | aksu
# Processing Record 9 of Set 9 | la asuncion
# Processing Record 10 of Set 9 | northam
# Processing Record 11 of Set 9 | anadyr
# Processing Record 12 of Set 9 | nabire
# Processing Record 13 of Set 9 | razole
# Processing Record 14 of Set 9 | praia
# Processing Record 15 of Set 9 | mayskiy
# Processing Record 16 of Set 9 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 17 of Set 9 | baker city
# Processing Record 18 of Set 9 | chapais
# Processing Record 19 of Set 9 | pavino
# Processing Record 20 of Set 9 | boatlaname
# City not found. Skipping...
# Processing Record 21 of Set 9 | oktyabrskiy
# Processing Record 22 of Set 9 | zanjan
# Processing Record 23 of Set 9 | bandarbeyla
# Processing Record 24 of Set 9 | high rock
# Processing Record 25 of Set 9 | charters towers
# Processing Record 26 of Set 9 | pastavy
# Processing Record 27 of Set 9 | tadine
# Processing Record 28 of Set 9 | touros
# Processing Record 29 of Set 9 | presidente epitacio
# Processing Record 30 of Set 9 | morgan city
# Processing Record 31 of Set 9 | nargana
# Processing Record 32 of Set 9 | kidal
# Processing Record 33 of Set 9 | chokwe
# Processing Record 34 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 9 | ixtapa
# Processing Record 36 of Set 9 | mehamn
# Processing Record 37 of Set 9 | ksenyevka
# City not found. Skipping...
# Processing Record 38 of Set 9 | luganville
# Processing Record 39 of Set 9 | itupiranga
# Processing Record 40 of Set 9 | siirt
# Processing Record 41 of Set 9 | bathsheba
# Processing Record 42 of Set 9 | agua dulce
# Processing Record 43 of Set 9 | khartoum
# Processing Record 44 of Set 9 | kargil
# Processing Record 45 of Set 9 | acapulco
# Processing Record 46 of Set 9 | mirabad
# Processing Record 47 of Set 9 | denpasar
# Processing Record 48 of Set 9 | port elizabeth
# Processing Record 49 of Set 9 | ust-nera
# Processing Record 0 of Set 10 | aykhal
# Processing Record 1 of Set 10 | mae hong son
# Processing Record 2 of Set 10 | baykit
# Processing Record 3 of Set 10 | port macquarie
# Processing Record 4 of Set 10 | burica
# City not found. Skipping...
# Processing Record 5 of Set 10 | meulaboh
# Processing Record 6 of Set 10 | chicama
# Processing Record 7 of Set 10 | sabang
# Processing Record 8 of Set 10 | pevek
# Processing Record 9 of Set 10 | niksar
# Processing Record 10 of Set 10 | songjianghe
# Processing Record 11 of Set 10 | dzilam gonzalez
# Processing Record 12 of Set 10 | toamua
# City not found. Skipping...
# Processing Record 13 of Set 10 | launceston
# Processing Record 14 of Set 10 | batsfjord
# Processing Record 15 of Set 10 | hofn
# Processing Record 16 of Set 10 | deputatskiy
# Processing Record 17 of Set 10 | mach
# Processing Record 18 of Set 10 | itubera
# Processing Record 19 of Set 10 | rio grande
# Processing Record 20 of Set 10 | makakilo city
# Processing Record 21 of Set 10 | aksarka
# Processing Record 22 of Set 10 | zharkent
# Processing Record 23 of Set 10 | pushchino
# Processing Record 24 of Set 10 | casablanca
# Processing Record 25 of Set 10 | ordu
# Processing Record 26 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 10 | samdari
# Processing Record 28 of Set 10 | mandalgovi
# Processing Record 29 of Set 10 | hoa binh
# Processing Record 30 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 10 | aqtobe
# Processing Record 32 of Set 10 | trat
# Processing Record 33 of Set 10 | olinda
# Processing Record 34 of Set 10 | zhuhai
# Processing Record 35 of Set 10 | juneau
# Processing Record 36 of Set 10 | tatarsk
# Processing Record 37 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 38 of Set 10 | verkhnevilyuysk
# Processing Record 39 of Set 10 | marystown
# Processing Record 40 of Set 10 | zonguldak
# Processing Record 41 of Set 10 | casper
# Processing Record 42 of Set 10 | qazvin
# Processing Record 43 of Set 10 | vila velha
# Processing Record 44 of Set 10 | okha
# Processing Record 45 of Set 10 | santiago de cao
# Processing Record 46 of Set 10 | mahibadhoo
# Processing Record 47 of Set 10 | acari
# Processing Record 48 of Set 10 | ruy barbosa
# Processing Record 49 of Set 10 | pangnirtung
# Processing Record 0 of Set 11 | nouakchott
# Processing Record 1 of Set 11 | bodden town
# Processing Record 2 of Set 11 | quang ngai
# Processing Record 3 of Set 11 | lithgow
# Processing Record 4 of Set 11 | ostrovnoy
# Processing Record 5 of Set 11 | duluth
# Processing Record 6 of Set 11 | lubango
# Processing Record 7 of Set 11 | namie
# Processing Record 8 of Set 11 | gwembe
# Processing Record 9 of Set 11 | boyolangu
# Processing Record 10 of Set 11 | phan rang
# City not found. Skipping...
# Processing Record 11 of Set 11 | pinheiro machado
# Processing Record 12 of Set 11 | kalomo
# City not found. Skipping...
# Processing Record 13 of Set 11 | roblin
# Processing Record 14 of Set 11 | san ignacio
# Processing Record 15 of Set 11 | dauphin
# Processing Record 16 of Set 11 | mogadishu
# Processing Record 17 of Set 11 | lavrentiya
# Processing Record 18 of Set 11 | plastunovskaya
# Processing Record 19 of Set 11 | genhe
# Processing Record 20 of Set 11 | quatre cocos
# Processing Record 21 of Set 11 | liverpool
# Processing Record 22 of Set 11 | arys
# Processing Record 23 of Set 11 | atagay
# Processing Record 24 of Set 11 | atar
# Processing Record 25 of Set 11 | ca mau
# Processing Record 26 of Set 11 | verkhoyansk
# Processing Record 27 of Set 11 | rio claro
# Processing Record 28 of Set 11 | arlit
# Processing Record 29 of Set 11 | karauzyak
# City not found. Skipping...
# Processing Record 30 of Set 11 | balykshi
# Processing Record 31 of Set 11 | monrovia
# Processing Record 32 of Set 11 | sisimiut
# Processing Record 33 of Set 11 | manokwari
# Processing Record 34 of Set 11 | rajapur
# Processing Record 35 of Set 11 | clyde river
# Processing Record 36 of Set 11 | liku
# Processing Record 37 of Set 11 | albert
# Processing Record 38 of Set 11 | beloha
# Processing Record 39 of Set 11 | hoi an
# Processing Record 40 of Set 11 | hvammstangi
# City not found. Skipping...
# Processing Record 41 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 42 of Set 11 | barcelona
# Processing Record 43 of Set 11 | la ronge
# Processing Record 44 of Set 11 | agropoli
# Processing Record 45 of Set 11 | peace river
# Processing Record 46 of Set 11 | pundaguitan
# Processing Record 47 of Set 11 | vestmannaeyjar
# Processing Record 48 of Set 11 | hirara
# Processing Record 49 of Set 11 | belogorsk
# Processing Record 0 of Set 12 | manassas park
# Processing Record 1 of Set 12 | fort-shevchenko
# Processing Record 2 of Set 12 | muravlenko
# Processing Record 3 of Set 12 | zhuanghe
# Processing Record 4 of Set 12 | katobu
# Processing Record 5 of Set 12 | batemans bay
# Processing Record 6 of Set 12 | katima mulilo
# Processing Record 7 of Set 12 | hay river
# Processing Record 8 of Set 12 | codrington
# Processing Record 9 of Set 12 | taltal
# Processing Record 10 of Set 12 | katherine
# Processing Record 11 of Set 12 | hobyo
# Processing Record 12 of Set 12 | general pico
# Processing Record 13 of Set 12 | shimanovsk
# Processing Record 14 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 15 of Set 12 | sambava
# Processing Record 16 of Set 12 | anapskaya
# Processing Record 17 of Set 12 | romny
# Processing Record 18 of Set 12 | basco
# Processing Record 19 of Set 12 | sheltozero
# Processing Record 20 of Set 12 | champerico
# Processing Record 21 of Set 12 | naruja
# Processing Record 22 of Set 12 | iqaluit
# Processing Record 23 of Set 12 | valparaiso
# Processing Record 24 of Set 12 | ilheus
# Processing Record 25 of Set 12 | sakakah
# Processing Record 26 of Set 12 | guilin
# Processing Record 27 of Set 12 | porto novo
# Processing Record 28 of Set 12 | bereda
# Processing Record 29 of Set 12 | oktyabrskoye
# Processing Record 30 of Set 12 | nyurba
# Processing Record 31 of Set 12 | sokolo
# Processing Record 32 of Set 12 | blagoyevo
# Processing Record 33 of Set 12 | sicamous
# Processing Record 34 of Set 12 | lander
# Processing Record 35 of Set 12 | krasnorechenskiy
# Processing Record 36 of Set 12 | krasnoselkup
# Processing Record 37 of Set 12 | ust-maya
# Processing Record 38 of Set 12 | calvinia
# Processing Record 39 of Set 12 | erenhot
# Processing Record 40 of Set 12 | simeykyne
# Processing Record 41 of Set 12 | kupang
# Processing Record 42 of Set 12 | umm durman
# City not found. Skipping...
# Processing Record 43 of Set 12 | davila
# Processing Record 44 of Set 12 | requena
# Processing Record 45 of Set 12 | bucine
# Processing Record 46 of Set 12 | lorengau
# Processing Record 47 of Set 12 | erzin
# Processing Record 48 of Set 12 | visnes
# Processing Record 49 of Set 12 | dunedin
# Processing Record 0 of Set 13 | gigmoto
# Processing Record 1 of Set 13 | rawannawi
# City not found. Skipping...
# Processing Record 2 of Set 13 | linkoping
# Processing Record 3 of Set 13 | laguna
# Processing Record 4 of Set 13 | buala
# Processing Record 5 of Set 13 | nhulunbuy
# Processing Record 6 of Set 13 | kyshtovka
# Processing Record 7 of Set 13 | picota
# Processing Record 8 of Set 13 | leningradskiy
# Processing Record 9 of Set 13 | sarab
# Processing Record 10 of Set 13 | srivardhan
# Processing Record 11 of Set 13 | garmisch-partenkirchen
# Processing Record 12 of Set 13 | lodeynoye pole
# Processing Record 13 of Set 13 | salamiyah
# Processing Record 14 of Set 13 | tapes
# Processing Record 15 of Set 13 | sibolga
# Processing Record 16 of Set 13 | larsnes
# Processing Record 17 of Set 13 | moose factory
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         faanui -16.4833 -151.7500     26.58        70          96
# 1  wichita falls  33.9137  -98.4934      1.25        77          40
# 2      busselton -33.6500  115.3333     20.70        72           0
# 3      carnarvon -24.8667  113.6333     24.47        76           6
# 4   saint george  37.1041 -113.5841     -1.67        64           0
#
#    Wind Speed Country        Date
# 0        2.50      PF  1674394452
# 1        5.14      US  1674394453
# 2        4.63      AU  1674394453
# 3        8.98      AU  1674394447
# 4        3.09      US  1674394453

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faanui -16.4833 -151.7500     26.58        70          96
# 1        wichita falls  33.9137  -98.4934      1.25        77          40
# 2            busselton -33.6500  115.3333     20.70        72           0
# 3            carnarvon -24.8667  113.6333     24.47        76           6
# 4         saint george  37.1041 -113.5841     -1.67        64           0
#
#          Wind Speed Country        Date
# City_ID
# 0              2.50      PF  1674394452
# 1              5.14      US  1674394453
# 2              4.63      AU  1674394453
# 3              8.98      AU  1674394447
# 4              3.09      US  1674394453

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.figure(figsize=(10,6))
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,3])

# Incorporate the other graph properties
plt.title('City Latitude vs. Max temperature')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.figure(figsize=(10,6))
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,4])

# Incorporate the other graph properties
plt.title('City Latitude vs. Humidity')
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.figure(figsize=(10,6))
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,5])

# Incorporate the other graph properties
plt.title('City Latitude vs. Cloudiness')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.figure(figsize=(10,6))
plt.scatter(city_data_df.iloc[:,1],city_data_df.iloc[:,6])

# Incorporate the other graph properties
plt.title('City Latitude vs. Wind Speed')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def lin_reg(x_values, y_values,y_label,x,y,filename,title):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
    plt.figure(figsize=(10,6))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.annotate(line_eq,(x,y),fontsize=12,color="red")
    print(f"The r-value is: {rvalue**2}")
    plt.savefig("output_data/"+ filename + ".png")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"]>=0,:]

# Display sample data
northern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1        wichita falls  33.9137  -98.4934      1.25        77          40
# 4         saint george  37.1041 -113.5841     -1.67        64           0
# 5               marzuq  14.4000   46.4667     23.88        29          58
# 7           georgetown   5.4112  100.3354     25.97        94          20
# 8          provideniya  64.3833 -173.3000    -26.09        87         100
#
#          Wind Speed Country        Date
# City_ID
# 1              5.14      US  1674394453
# 4              3.09      US  1674394453
# 5              1.87      YE  1674394455
# 7              0.00      MY  1674394339
# 8              6.94      RU  1674394456

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"]< 0,:]

# Display sample data
southern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           faanui -16.4833 -151.7500     26.58        70          96
# 2        busselton -33.6500  115.3333     20.70        72           0
# 3        carnarvon -24.8667  113.6333     24.47        76           6
# 6           burnie -41.0667  145.9167     15.19        90          15
# 14          mungwi -10.1732   31.3694     22.22        70         100
#
#          Wind Speed Country        Date
# City_ID
# 0              2.50      PF  1674394452
# 2              4.63      AU  1674394453
# 3              8.98      AU  1674394447
# 6              3.67      AU  1674394455
# 14             2.34      ZM  1674394460

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
nth_hem_lat = northern_hemi_df.iloc[:,1]
nth_hem_temp = northern_hemi_df.iloc[:,3]

lin_reg(nth_hem_lat, nth_hem_temp,'Max Temp',10,2,'Fig5','Northern Hemisphere-Latitude Vs Temperature')
# Out:
# The r-value is: 0.6710404143511933

# %%
# Linear regression on Southern Hemisphere
sth_hem_lat = southern_hemi_df.iloc[:,1]
sth_hem_temp = southern_hemi_df.iloc[:,3]

lin_reg(sth_hem_lat, sth_hem_temp,'Max Temp',-30,15,'Fig6','Southern Hemisphere-Latitude Vs Temperature')
# Out:
# The r-value is: 0.19154562048211324

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nth_hem_humid = northern_hemi_df.iloc[:,4]

lin_reg(nth_hem_lat, nth_hem_humid,'Humidity',50,40,'Fig7','Northern Hemisphere-Latitude Vs Humidity')
# Out:
# The r-value is: 0.18582596706828527

# %%
# Southern Hemisphere
sth_hem_humid= southern_hemi_df.iloc[:,4]

lin_reg(sth_hem_lat, sth_hem_humid,'Humidity',-20,45,'Fig8','Southern Hemisphere-Latitude Vs Humidity')
# Out:
# The r-value is: 0.10966289565475033

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nth_hem_cloud = northern_hemi_df.iloc[:,5]

lin_reg(nth_hem_lat, nth_hem_cloud,'Cloudiness',50,58,'Fig9','Northern Hemisphere-Latitude Vs Cloudiness')
# Out:
# The r-value is: 0.09028414294649771

# %%
# Southern Hemisphere
sth_hem_cloud = southern_hemi_df.iloc[:,5]

lin_reg(sth_hem_lat, sth_hem_cloud,'Cloudiness',-40,55,'Fig10','Southern Hemisphere-Latitude Vs Cloudiness')
# Out:
# The r-value is: 0.19384409898761099

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
nth_hem_wind = northern_hemi_df.iloc[:,6]

lin_reg(nth_hem_lat, nth_hem_wind,'Wind Speed',20,10,'Fig11','Northern Hemisphere-Latitude Vs Wind Speed')
# Out:
# The r-value is: 0.020904440715694722

# %%
# Southern Hemisphere
sth_hem_wind = southern_hemi_df.iloc[:,6]

lin_reg(sth_hem_lat, sth_hem_wind,'Wind Speed',-50,6,'Fig12','Southern Hemisphere-Latitude Vs Wind Speed')
# Out:
# The r-value is: 0.0881192408773937

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
